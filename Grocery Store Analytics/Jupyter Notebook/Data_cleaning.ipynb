# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 3.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.3/9.8 MB 3.8 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/9.8 MB 3.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/9.8 MB 3.5 MB/s eta 0:00:03
#    ------------- -------------------------- 3.4/9.8 MB 3.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.8 MB 3.6 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.8 MB 3.7 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.8 MB 3.7 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/9.8 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.8 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.8 MB 3.9 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
file_path = r"C:\Users\Admin\Desktop\Grocery Store Analytics\Data Set\Raw data\grocery_sales.csv"

# Load and view the data
sales = pd.read_csv(file_path)
sales.head()
# Out:
#    Order_ID  Order_Date Customer_ID Product_ID Store_ID  Quantity  Unit_Price  \
# 0  ORD00001  2024-11-06       C0240       P035     S004         1         300
# 1  ORD00002  2024-05-07       C0082       P041     S001         2          30
# 2  ORD00003  2026-09-06       C0044       P096     S003         2         500
# 3  ORD00004  2025-12-02       C0066       P096     S007         2         500
# 4  ORD00005  2025-06-25       C0365       P067     S006         2         450
#
#    Unit_Cost  Discount_Percent  Gross_Sales  ...  Profit  Payment_Method  \
# 0        150                 5          300  ...   135.0     Credit Card
# 1         20                 5           60  ...    17.0     Credit Card
# 2        260                 0         1000  ...   480.0             UPI
# 3        260                15         1000  ...   330.0      Debit Card
# 4        280                 0          900  ...   340.0             UPI
#
# ...

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          3000 non-null   str
#  1   Order_Date        3000 non-null   str
#  2   Customer_ID       3000 non-null   str
#  3   Product_ID        3000 non-null   str
#  4   Store_ID          3000 non-null   str
#  5   Quantity          3000 non-null   int64
#  6   Unit_Price        3000 non-null   int64
#  7   Unit_Cost         3000 non-null   int64
#  8   Discount_Percent  3000 non-null   int64
#  9   Gross_Sales       3000 non-null   int64
#  10  Discount_Amount   3000 non-null   float64
#  11  Revenue           3000 non-null   float64
#  12  Profit            3000 non-null   float64
#  13  Payment_Method    3000 non-null   str
#  14  Product_Name      3000 non-null   str
#  15  Category          3000 non-null   str
#  16  Customer_Name     3000 non-null   str
# ...

# %%
sales.shape
# Out:
# (3000, 22)

# %%
#missing value
sales.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_ID         0
# Product_ID          0
# Store_ID            0
# Quantity            0
# Unit_Price          0
# Unit_Cost           0
# Discount_Percent    0
# Gross_Sales         0
# Discount_Amount     0
# Revenue             0
# Profit              0
# Payment_Method      0
# Product_Name        0
# Category            0
# Customer_Name       0
# City                0
# Age_Group           0
# Member_Type         0
# Store_Name          0
# Store_Type          0
# dtype: int64

# %%
#Duplicates value
sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
#data types
sales["Order_Date"] = pd.to_datetime(
    sales["Order_Date"],
    errors="coerce"
)

# %%
#invalid Values
sales.describe()
# Out:
#                        Order_Date     Quantity   Unit_Price    Unit_Cost  \
# count                        3000  3000.000000  3000.000000  3000.000000
# mean   2025-06-20 10:59:02.400000     1.908000   400.540000   237.314000
# min           2024-01-01 00:00:00     1.000000    30.000000    15.000000
# 25%           2024-09-21 18:00:00     1.000000   140.000000    75.000000
# 50%           2025-06-11 12:00:00     2.000000   280.000000   150.000000
# 75%           2026-03-20 06:00:00     2.000000   450.000000   280.000000
# max           2026-12-31 00:00:00     5.000000  2500.000000  1700.000000
# std                           NaN     1.050033   420.870826   270.591334
#
#        Discount_Percent   Gross_Sales  Discount_Amount       Revenue  \
# count       3000.000000   3000.000000      3000.000000   3000.000000
# mean           5.456667    761.136667        41.827083    719.309583
# min            0.000000     30.000000         0.000000     24.000000
# ...

# %%
sales[
    (sales["Quantity"] <= 0) |
    (sales["Unit_Price"] <= 0) |
    (sales["Discount_Percent"] < 0) |
    (sales["Discount_Percent"] > 100)
]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Product_ID, Store_ID, Quantity, Unit_Price, Unit_Cost, Discount_Percent, Gross_Sales, Discount_Amount, Revenue, Profit, Payment_Method, Product_Name, Category, Customer_Name, City, Age_Group, Member_Type, Store_Name, Store_Type]
# Index: []
#
# [0 rows x 22 columns]

# %%
output_path = r"C:\Users\Admin\Desktop\Grocery Store Analytics\Data Set\Cleaned data\sales_cleaned.csv"

# Save the DataFrame to that path
sales.to_csv(output_path, index=False)
